# %%
import random
N=int(input ("enter the number of people in lottery:"))
list=[]
for i in range(N):
 s=input("enter the name:")
 list.append(s)
r=random.randint(0,N-1)
print(" winner of  lottery:",list[r])
# Out:
# enter the number of people in lottery:1
